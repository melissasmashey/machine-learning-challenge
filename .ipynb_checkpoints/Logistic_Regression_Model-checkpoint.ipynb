# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\msmas\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\msmas\anaconda3\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\msmas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\msmas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\msmas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\msmas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\msmas\anaconda3\lib\site-packages (0.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co','koi_fpflag_ec',
                        'koi_period','koi_period_err1','koi_period_err2',
                        'koi_time0bk','koi_time0bk_err1','koi_time0bk_err2',
                        'koi_impact','koi_impact_err1','koi_impact_err2',
                        'koi_duration','koi_duration_err1','koi_duration_err2',
                        'koi_depth','koi_depth_err1','koi_depth_err2',
                        'koi_prad','koi_prad_err1','koi_prad_err2',
                        'koi_teq','koi_insol','koi_insol_err1','koi_insol_err2',
                        'koi_model_snr','koi_steff','koi_steff_err1','koi_steff_err2',
                        'koi_slogg','koi_slogg_err1','koi_slogg_err2',
                        'koi_srad','koi_srad_err1','koi_srad_err2',
                        'ra','dec','koi_kepmag']]
selected_features.head(10)
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
# 5              0              0              0              0    2.566589
# 6              0              0              0              0   16.068647
# 7              0              0              0              0    2.470613
# 8              0              1              0              0    2.204735
# 9              0              0              0              0    3.522498
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
# 5     1.780000e-05    -1.780000e-05   179.554370          0.004610
# 6     1.090000e-05    -1.090000e-05   173.621937          0.000517
# 7     2.700000e-08    -2.700000e-08   122.763305          0.000009
# 8     4.300000e-08    -4.300000e-08   121.358542          0.000016
# 9     1.980000e-07    -1.980000e-07   121.119423          0.000047
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
# 5         -0.004610  ...            -232      4.486           0.054
# 6         -0.000517  ...             -83      4.485           0.083
# 7         -0.000009  ...             -78      4.457           0.024
# 8         -0.000016  ...             -89      4.019           0.033
# 9         -0.000047  ...            -137      4.169           0.055
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
# 5          -0.229     0.972          0.315         -0.105  296.28613
# 6          -0.028     0.848          0.033         -0.072  286.99948
# 7          -0.024     0.964          0.038         -0.038  286.80847
# 8          -0.027     1.952          0.099         -0.110  292.24728
# 9          -0.045     1.451          0.110         -0.110  281.28812
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
# 5  48.224670      15.714
# 6  48.375790      15.841
# 7  49.316399      11.338
# 8  47.969521      10.463
# 9  42.451080      13.563
#
# [10 rows x 39 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df["koi_disposition"]
X = selected_features

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 39 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler,StandardScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver = "liblinear")
model.fit(X_train_scaled, y_train)

print(f"Training Data Score: {model.score(X_train_scaled,y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test )}")
# Out:
# Training Data Score: 0.8367346938775511
# Testing Data Score: 0.8329519450800915

# %%
from sklearn.metrics import classification_report
predictions = model.predict(X_test_scaled)
print(classification_report(y_test, predictions,
                            target_names=["candidate", "false positive","confirmed"]))
# Out:
#                 precision    recall  f1-score   support
#
#      candidate       0.67      0.61      0.64       411
# false positive       0.70      0.73      0.71       484
#      confirmed       0.98      1.00      0.99       853
#
#       accuracy                           0.83      1748
#      macro avg       0.78      0.78      0.78      1748
#   weighted avg       0.83      0.83      0.83      1748

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [10, 50, 100],
              'max_iter': [200, 500, 800]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=10, max_iter=200 ..............................................
# [CV] .................. C=10, max_iter=200, score=0.876, total=   0.1s
# [CV] C=10, max_iter=200 ..............................................
# [CV] .................. C=10, max_iter=200, score=0.853, total=   0.1s
# [CV] C=10, max_iter=200 ..............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] .................. C=10, max_iter=200, score=0.870, total=   0.1s
# [CV] C=10, max_iter=200 ..............................................
# [CV] .................. C=10, max_iter=200, score=0.851, total=   0.1s
# [CV] C=10, max_iter=200 ..............................................
# [CV] .................. C=10, max_iter=200, score=0.859, total=   0.1s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.876, total=   0.1s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.853, total=   0.1s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.870, total=   0.1s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.851, total=   0.1s
# [CV] C=10, max_iter=500 ..............................................
# [CV] .................. C=10, max_iter=500, score=0.859, total=   0.1s
# [CV] C=10, max_iter=800 ..............................................
# [CV] .................. C=10, max_iter=800, score=0.876, total=   0.1s
# [CV] C=10, max_iter=800 ..............................................
# [CV] .................. C=10, max_iter=800, score=0.853, total=   0.1s
# [CV] C=10, max_iter=800 ..............................................
# [CV] .................. C=10, max_iter=800, score=0.870, total=   0.1s
# [CV] C=10, max_iter=800 ..............................................
# [CV] .................. C=10, max_iter=800, score=0.851, total=   0.1s
# [CV] C=10, max_iter=800 ..............................................
# [CV] .................. C=10, max_iter=800, score=0.859, total=   0.1s
# [CV] C=50, max_iter=200 ..............................................
# [CV] .................. C=50, max_iter=200, score=0.890, total=   0.2s
# [CV] C=50, max_iter=200 ..............................................
# [CV] .................. C=50, max_iter=200, score=0.869, total=   0.1s
# [CV] C=50, max_iter=200 ..............................................
# [CV] .................. C=50, max_iter=200, score=0.885, total=   0.1s
# [CV] C=50, max_iter=200 ..............................................
# [CV] .................. C=50, max_iter=200, score=0.856, total=   0.1s
# [CV] C=50, max_iter=200 ..............................................
# [CV] .................. C=50, max_iter=200, score=0.865, total=   0.1s
# [CV] C=50, max_iter=500 ..............................................
# [CV] .................. C=50, max_iter=500, score=0.890, total=   0.2s
# [CV] C=50, max_iter=500 ..............................................
# [CV] .................. C=50, max_iter=500, score=0.869, total=   0.1s
# [CV] C=50, max_iter=500 ..............................................
# [CV] .................. C=50, max_iter=500, score=0.885, total=   0.1s
# [CV] C=50, max_iter=500 ..............................................
# [CV] .................. C=50, max_iter=500, score=0.856, total=   0.1s
# [CV] C=50, max_iter=500 ..............................................
# [CV] .................. C=50, max_iter=500, score=0.865, total=   0.1s
# [CV] C=50, max_iter=800 ..............................................
# [CV] .................. C=50, max_iter=800, score=0.890, total=   0.2s
# [CV] C=50, max_iter=800 ..............................................
# [CV] .................. C=50, max_iter=800, score=0.869, total=   0.1s
# [CV] C=50, max_iter=800 ..............................................
# [CV] .................. C=50, max_iter=800, score=0.885, total=   0.1s
# [CV] C=50, max_iter=800 ..............................................
# [CV] .................. C=50, max_iter=800, score=0.856, total=   0.1s
# [CV] C=50, max_iter=800 ..............................................
# [CV] .................. C=50, max_iter=800, score=0.865, total=   0.1s
# [CV] C=100, max_iter=200 .............................................
# [CV] ................. C=100, max_iter=200, score=0.896, total=   0.1s
# [CV] C=100, max_iter=200 .............................................
# [CV] ................. C=100, max_iter=200, score=0.871, total=   0.2s
# [CV] C=100, max_iter=200 .............................................
# [CV] ................. C=100, max_iter=200, score=0.889, total=   0.2s
# [CV] C=100, max_iter=200 .............................................
# [CV] ................. C=100, max_iter=200, score=0.860, total=   0.2s
# [CV] C=100, max_iter=200 .............................................
# [CV] ................. C=100, max_iter=200, score=0.867, total=   0.2s
# [CV] C=100, max_iter=500 .............................................
# [CV] ................. C=100, max_iter=500, score=0.896, total=   0.2s
# [CV] C=100, max_iter=500 .............................................
# [CV] ................. C=100, max_iter=500, score=0.871, total=   0.2s
# [CV] C=100, max_iter=500 .............................................
# [CV] ................. C=100, max_iter=500, score=0.889, total=   0.2s
# [CV] C=100, max_iter=500 .............................................
# [CV] ................. C=100, max_iter=500, score=0.860, total=   0.2s
# [CV] C=100, max_iter=500 .............................................
# [CV] ................. C=100, max_iter=500, score=0.867, total=   0.2s
# [CV] C=100, max_iter=800 .............................................
# [CV] ................. C=100, max_iter=800, score=0.896, total=   0.2s
# [CV] C=100, max_iter=800 .............................................
# [CV] ................. C=100, max_iter=800, score=0.871, total=   0.1s
# [CV] C=100, max_iter=800 .............................................
# [CV] ................. C=100, max_iter=800, score=0.889, total=   0.2s
# [CV] C=100, max_iter=800 .............................................
# [CV] ................. C=100, max_iter=800, score=0.860, total=   0.2s
# [CV] C=100, max_iter=800 .............................................
# [CV] ................. C=100, max_iter=800, score=0.867, total=   0.2s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    6.3s finished
# GridSearchCV(estimator=LogisticRegression(solver='liblinear'),
#              param_grid={'C': [10, 50, 100], 'max_iter': [200, 500, 800]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100, 'max_iter': 200}
# 0.8767830503787686

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Logistic_Regression_Model.sav'
joblib.dump(model, filename)
# Out:
# ['Logistic_Regression_Model.sav']
